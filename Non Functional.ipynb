# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')
# %run -i 'functions.py'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ERROR:root:File `'functions.py'` not found.

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('testset.csv')

# %%
df
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 0      50785         0.0    2013-02-04                    Dmdd        1996
# 1      51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2      17168         0.0    2013-02-01                     NaN        1567
# 3      45559         0.0    2013-01-22              Finn Water         267
# 4      49871       500.0    2013-03-27                  Bruder        1260
# ...      ...         ...           ...                     ...         ...
# 14845  39307         0.0    2011-02-24                  Danida          34
# 14846  18990      1000.0    2011-03-21                    Hiap           0
# 14847  28749         0.0    2013-03-04                     NaN        1476
# 14848  33492         0.0    2013-02-18                 Germany         998
# 14849  68707         0.0    2013-02-13  Government Of Tanzania         481
#
#         installer  longitude   latitude                 wpt_name  num_private  \
# 0            DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1             DWE  36.656709  -3.309214                  Kimnyak            0
# 2             NaN  34.767863  -5.004344           Puma Secondary            0
# 3      FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4          BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
# ...           ...        ...        ...                      ...          ...
# 14845          Da  38.852669  -6.582841                Kwambwezi            0
# 14846        HIAP  37.451633  -5.350428         Bonde La Mkondoa            0
# 14847         NaN  34.739804  -4.585587                  Bwawani            0
# 14848         DWE  35.432732 -10.584159                 Kwa John            0
# 14849  Government  34.765054 -11.226012         Kwa Mzee Chagala            0
#
#                          basin   subvillage   region  region_code  \
# 0                     Internal       Magoma  Manyara           21
# 1                      Pangani      Kimnyak   Arusha            2
# 2                     Internal        Msatu  Singida           13
# 3      Ruvuma / Southern Coast   Kipindimbi    Lindi           80
# 4      Ruvuma / Southern Coast      Losonga   Ruvuma           10
# ...                        ...          ...      ...          ...
# 14845              Wami / Ruvu        Yombo    Pwani            6
# 14846                  Pangani      Mkondoa    Tanga            4
# 14847                 Internal       Juhudi  Singida           13
# 14848               Lake Nyasa  Namakinga B   Ruvuma           10
# 14849               Lake Nyasa        Kamba   Ruvuma           10
#
#        district_code            lga          ward  population public_meeting  \
# 0                  3          Mbulu        Bashay         321           True
# 1                  2   Arusha Rural      Kimnyaki         300           True
# 2                  2  Singida Rural          Puma         500           True
# 3                 43         Liwale       Mkutano         250            NaN
# 4                  3         Mbinga  Mbinga Urban          60            NaN
# ...              ...            ...           ...         ...            ...
# 14845              1       Bagamoyo         Yombo          20           True
# 14846              7        Kilindi       Mvungwe        2960           True
# 14847              2  Singida Rural       Ughandi         200           True
# 14848              2   Songea Rural      Maposeni         150           True
# 14849              3         Mbinga    Mbamba bay          40           True
#
#                    recorded_by scheme_management                scheme_name  \
# 0      GeoData Consultants Ltd        Parastatal                        NaN
# 1      GeoData Consultants Ltd               VWC             TPRI pipe line
# 2      GeoData Consultants Ltd               VWC                          P
# 3      GeoData Consultants Ltd               VWC                        NaN
# 4      GeoData Consultants Ltd       Water Board                     BRUDER
# ...                        ...               ...                        ...
# 14845  GeoData Consultants Ltd               VWC              Bagamoyo wate
# 14846  GeoData Consultants Ltd               VWC                        NaN
# 14847  GeoData Consultants Ltd               VWC                        NaN
# 14848  GeoData Consultants Ltd               VWC  Mradi wa maji wa maposeni
# 14849  GeoData Consultants Ltd               VWC                     DANIDA
#
#       permit  construction_year extraction_type extraction_type_group  \
# 0       True               2012           other                 other
# 1       True               2000         gravity               gravity
# 2        NaN               2010           other                 other
# 3       True               1987           other                 other
# 4       True               2000         gravity               gravity
# ...      ...                ...             ...                   ...
# 14845   True               1988            mono                  mono
# 14846  False               1994     nira/tanira           nira/tanira
# 14847    NaN               2010         gravity               gravity
# 14848   True               2009         gravity               gravity
# 14849   True               2008         gravity               gravity
#
#       extraction_type_class   management management_group       payment  \
# 0                     other   parastatal       parastatal     never pay
# 1                   gravity          vwc       user-group     never pay
# 2                     other          vwc       user-group     never pay
# 3                     other          vwc       user-group       unknown
# 4                   gravity  water board       user-group   pay monthly
# ...                     ...          ...              ...           ...
# 14845             motorpump          vwc       user-group     never pay
# 14846              handpump          vwc       user-group  pay annually
# 14847               gravity          vwc       user-group     never pay
# 14848               gravity          vwc       user-group     never pay
# 14849               gravity          vwc       user-group     never pay
#
#       payment_type water_quality quality_group      quantity quantity_group  \
# 0        never pay          soft          good      seasonal       seasonal
# 1        never pay          soft          good  insufficient   insufficient
# 2        never pay          soft          good  insufficient   insufficient
# 3          unknown          soft          good           dry            dry
# 4          monthly          soft          good        enough         enough
# ...            ...           ...           ...           ...            ...
# 14845    never pay          soft          good        enough         enough
# 14846     annually         salty         salty  insufficient   insufficient
# 14847    never pay          soft          good  insufficient   insufficient
# 14848    never pay          soft          good  insufficient   insufficient
# 14849    never pay          soft          good           dry            dry
#
#                      source           source_type source_class  \
# 0      rainwater harvesting  rainwater harvesting      surface
# 1                    spring                spring  groundwater
# 2      rainwater harvesting  rainwater harvesting      surface
# 3              shallow well          shallow well  groundwater
# 4                    spring                spring  groundwater
# ...                     ...                   ...          ...
# 14845                 river            river/lake      surface
# 14846          shallow well          shallow well  groundwater
# 14847                   dam                   dam      surface
# 14848                 river            river/lake      surface
# 14849                spring                spring  groundwater
#
#           waterpoint_type waterpoint_type_group
# 0                   other                 other
# 1      communal standpipe    communal standpipe
# 2                   other                 other
# 3                   other                 other
# 4      communal standpipe    communal standpipe
# ...                   ...                   ...
# 14845  communal standpipe    communal standpipe
# 14846           hand pump             hand pump
# 14847  communal standpipe    communal standpipe
# 14848  communal standpipe    communal standpipe
# 14849  communal standpipe    communal standpipe
#
# [14850 rows x 40 columns]

# %%
df.drop(columns=['wpt_name','num_private','subvillage','region_code', 'recorded_by',
            
                 'scheme_name','quantity_group','source_type',
                 'ward', 
                 'source_class','quality_group', 'quantity_group',
                'extraction_type','extraction_type_group','management_group','payment_type',
                 'waterpoint_type_group'],inplace=True )

# %%
df['funder'].fillna('0', inplace=True)
df['scheme_management'].fillna('0', inplace=True)
df['installer'].fillna('0', inplace=True)

# %%
df.drop(columns=['public_meeting','permit'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                       0
# amount_tsh               0
# date_recorded            0
# funder                   0
# gps_height               0
# installer                0
# longitude                0
# latitude                 0
# basin                    0
# region                   0
# district_code            0
# lga                      0
# population               0
# scheme_management        0
# construction_year        0
# extraction_type_class    0
# management               0
# payment                  0
# water_quality            0
# quantity                 0
# source                   0
# waterpoint_type          0
# dtype: int64

# %%
df.shape
# Out:
# (14850, 22)
